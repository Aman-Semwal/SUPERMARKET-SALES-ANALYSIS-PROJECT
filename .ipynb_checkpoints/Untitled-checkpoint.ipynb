# %% [markdown]
# # SUPERMARKET SALES ANALYSIS (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("SalesAnalysis.csv")
df.head()
# Out:
#   Order ID Customer Name          Category      Sub Category         City  \
# 0      OD1        Harish      Oil & Masala           Masalas      Vellore
# 1      OD2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2      OD3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3      OD4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4      OD5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %% [markdown]
# ## Understanding the Dataset

# %%
df.shape
print("No. of rows:",df.shape[0])
print("No. of columns:",df.shape[1])
# Out:
# No. of rows: 9994
# No. of columns: 11

# %%
df.dtypes
# Out:
# Order ID          object
# Customer Name     object
# Category          object
# Sub Category      object
# City              object
# Order Date        object
# Region            object
# Sales              int64
# Discount         float64
# Profit           float64
# State             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Customer Name  9994 non-null   object
#  2   Category       9994 non-null   object
#  3   Sub Category   9994 non-null   object
#  4   City           9994 non-null   object
#  5   Order Date     9994 non-null   object
#  6   Region         9994 non-null   object
#  7   Sales          9994 non-null   int64
#  8   Discount       9994 non-null   float64
#  9   Profit         9994 non-null   float64
#  10  State          9994 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 859.0+ KB

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df = df.drop(columns=["Order ID","State"])
df = df.rename(columns={"Sub Category":"Sub_Category", "Order Date":"Order_Date"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer Name  9994 non-null   object
#  1   Category       9994 non-null   object
#  2   Sub_Category   9994 non-null   object
#  3   City           9994 non-null   object
#  4   Order_Date     9994 non-null   object
#  5   Region         9994 non-null   object
#  6   Sales          9994 non-null   int64
#  7   Discount       9994 non-null   float64
#  8   Profit         9994 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 702.8+ KB

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df[df['Order_Date'].isnull()]
# Out:
#      Customer Name           Category       Sub_Category         City  \
# 12          Sharon             Snacks            Cookies     Dindigul
# 14          Sundar  Eggs, Meat & Fish            Chicken  Kanyakumari
# 15          Ramesh       Oil & Masala  Edible Oil & Ghee  Krishnagiri
# 17          Arutra          Beverages      Health Drinks         Bodi
# 18         Haseena  Eggs, Meat & Fish             Mutton      Tenkasi
# ...            ...                ...                ...          ...
# 9985         Shree  Eggs, Meat & Fish             Mutton  Kanyakumari
# 9987        Ganesh   Fruits & Veggies   Fresh Vegetables        Theni
# 9989        Sudeep  Eggs, Meat & Fish               Eggs      Madurai
# 9992          Peer       Oil & Masala             Spices   Pudukottai
# 9993        Ganesh        Food Grains       Atta & Flour  Tirunelveli
#
#      Order_Date   Region  Sales  Discount  Profit
# 12          NaT    South   1659      0.19  315.21
# 14          NaT  Central    831      0.22  207.75
# 15          NaT  Central   1440      0.11  100.80
# 17          NaT     West   1617      0.19  113.19
# 18          NaT     West   1757      0.35  386.54
# ...         ...      ...    ...       ...     ...
# 9985        NaT     West   1286      0.30  475.82
# 9987        NaT     West   1350      0.15   67.50
# 9989        NaT     West    945      0.16  359.10
# 9992        NaT     West   1659      0.15  597.24
# 9993        NaT     West   1034      0.28  165.44
#
# [5952 rows x 9 columns]

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%m/%d/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer Name  9994 non-null   object
#  1   Category       9994 non-null   object
#  2   Sub_Category   9994 non-null   object
#  3   City           9994 non-null   object
#  4   Order_Date     4042 non-null   datetime64[ns]
#  5   Region         9994 non-null   object
#  6   Sales          9994 non-null   int64
#  7   Discount       9994 non-null   float64
#  8   Profit         9994 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 702.8+ KB

# %%
df["Order_Date"]
# Out:
# 0      2017-11-08
# 1      2017-11-08
# 2      2017-06-12
# 3      2016-10-11
# 4      2016-10-11
#           ...
# 9989          NaT
# 9990   2015-07-12
# 9991   2017-06-06
# 9992          NaT
# 9993          NaT
# Name: Order_Date, Length: 9994, dtype: datetime64[ns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#                           Order_Date        Sales     Discount       Profit
# count                           4042  9994.000000  9994.000000  9994.000000
# mean   2017-04-28 03:16:17.931716864  1496.596158     0.226817   374.937082
# min              2015-01-03 00:00:00   500.000000     0.100000    25.250000
# 25%              2016-05-09 06:00:00  1000.000000     0.160000   180.022500
# 50%              2017-07-01 00:00:00  1498.000000     0.230000   320.780000
# 75%              2018-06-01 00:00:00  1994.750000     0.290000   525.627500
# max              2018-12-11 00:00:00  2500.000000     0.350000  1120.950000
# std                              NaN   577.559036     0.074636   239.932881

# %%
# It displays the frequency distribution of sales values, helping to understand the most common sales ranges
fig = px.histogram(df, x='Sales', nbins=30, title='Sales Distribution')
fig.show()

# %%
# Create scatterplot of sales and profit
fig = px.scatter(df, x='Sales', y='Profit', title='Sales vs. Profit')
fig.show()

# %%
fig = px.box(df, x='Region', y='Sales', title='Sales by Region')
fig.show()

# %% [markdown]
# ## Analyzing Sales by Category and Sub-Category

# %%
category_sales = df.groupby(['Category', 'Sub_Category'])['Sales'].sum().reset_index()

# %%
fig = px.bar(category_sales, x='Category', y='Sales', color='Sub_Category', title='Total Sales by Category')
fig.show()

# %%
fig = px.pie(category_sales, values='Sales', names='Sub_Category', title='Total Sales by Sub-Category')
fig.show()

# %% [markdown]
# # Analysing Profit by category and sub-category

# %%
category_profit = df.groupby(['Category', 'Sub_Category'])['Profit'].sum().reset_index()
fig = px.bar(category_profit, x='Category', y='Profit', color='Sub_Category', title='Total Profit by Category')
fig.show()

# %%
fig = px.pie(category_profit, values='Profit', names='Sub_Category', title='Total Profit by Sub-Category')
fig.show()

# %% [markdown]
# ## Analyze Sales and Profit by region

# %%
sales_by_region = df.groupby('Region')['Sales'].sum().reset_index()
profit_by_region = df.groupby('Region')['Profit'].sum().reset_index()
sales_profit_by_region = pd.merge(sales_by_region, profit_by_region, on='Region')
sales_profit_by_region.head()
# Out:
#     Region    Sales      Profit
# 0  Central  3468156   856806.84
# 1     East  4248368  1074345.58
# 2    North     1254      401.28
# 3    South  2440461   623562.89
# 4     West  4798743  1192004.61

# %%
regions = sales_profit_by_region['Region']
sales = sales_profit_by_region['Sales']
profit = sales_profit_by_region['Profit']

x = np.arange(len(regions))  # positions
width = 0.35  # width of the bars

fig, ax = plt.subplots()
ax.bar(x - width/2, sales, width, label='Sales')
ax.bar(x + width/2, profit, width, label='Profit')

ax.set_xlabel('Region')
ax.set_ylabel('Amount')
ax.set_title('Total Sales and Profit by Region')
ax.set_xticks(x)
ax.set_xticklabels(regions)
ax.legend()

plt.show()

# %% [markdown]
# ## Analyze sales and profit by city

# %%
sales_by_city = df.groupby('City')['Sales'].sum().reset_index()
profit_by_city = df.groupby('City')['Profit'].sum().reset_index()
sales_profit_by_city = pd.merge(sales_by_city, profit_by_city, on='City')

sales_profit_by_city.head()
# Out:
#          City   Sales     Profit
# 0        Bodi  667177  173655.13
# 1     Chennai  634963  160921.33
# 2  Coimbatore  634748  157399.41
# 3      Cumbum  626047  156355.13
# 4  Dharmapuri  571553  141593.05

# %% [markdown]
# ## Analyze Discounts

# %%
df
# Out:
#      Customer Name           Category      Sub_Category         City  \
# 0           Harish       Oil & Masala           Masalas      Vellore
# 1            Sudha          Beverages     Health Drinks  Krishnagiri
# 2          Hussain        Food Grains      Atta & Flour   Perambalur
# 3          Jackson   Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4          Ridhesh        Food Grains   Organic Staples         Ooty
# ...            ...                ...               ...          ...
# 9989        Sudeep  Eggs, Meat & Fish              Eggs      Madurai
# 9990          Alan             Bakery          Biscuits  Kanyakumari
# 9991          Ravi        Food Grains              Rice         Bodi
# 9992          Peer       Oil & Masala            Spices   Pudukottai
# 9993        Ganesh        Food Grains      Atta & Flour  Tirunelveli
#
#      Order_Date Region  Sales  Discount  Profit
# 0    2017-11-08  North   1254      0.12  401.28
# 1    2017-11-08  South    749      0.18  149.80
# 2    2017-06-12   West   2360      0.21  165.20
# 3    2016-10-11  South    896      0.25   89.60
# 4    2016-10-11  South   2355      0.26  918.45
# ...         ...    ...    ...       ...     ...
# 9989        NaT   West    945      0.16  359.10
# 9990 2015-07-12   West   1195      0.26   71.70
# 9991 2017-06-06   West   1567      0.16  501.44
# 9992        NaT   West   1659      0.15  597.24
# 9993        NaT   West   1034      0.28  165.44
#
# [9994 rows x 9 columns]

# %%
df["Year"] = pd.DatetimeIndex(df["Order_Date"]).year

# %%
df.head()
# Out:
#   Customer Name          Category      Sub_Category         City Order_Date  \
# 0        Harish      Oil & Masala           Masalas      Vellore 2017-11-08
# 1         Sudha         Beverages     Health Drinks  Krishnagiri 2017-11-08
# 2       Hussain       Food Grains      Atta & Flour   Perambalur 2017-06-12
# 3       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri 2016-10-11
# 4       Ridhesh       Food Grains   Organic Staples         Ooty 2016-10-11
#
#   Region  Sales  Discount  Profit    Year
# 0  North   1254      0.12  401.28  2017.0
# 1  South    749      0.18  149.80  2017.0
# 2   West   2360      0.21  165.20  2017.0
# 3  South    896      0.25   89.60  2016.0
# 4  South   2355      0.26  918.45  2016.0

# %%
discount_by_year = df.groupby('Year')['Discount'].mean().reset_index()

fig = px.bar(discount_by_year, x='Year', y='Discount', title='Discount Percent  by Year')
fig.show()

# %%
discount_sales_by_region = df.groupby('Region')['Sales'].apply(lambda x: x[x!=0].sum()).reset_index()
discount_by_region = df.groupby('Region')['Discount'].mean().reset_index()

fig = px.scatter(discount_by_region, x='Discount', y=discount_sales_by_region['Sales'], color='Region',
                 title='Discount and Sales per Region')
fig.show()

# %%
discount_sales_by_city = df.groupby('City')['Sales'].apply(lambda x: x[x!=0].sum()).reset_index()
discount_by_city = df.groupby('City')['Discount'].mean().reset_index()

fig = px.scatter(discount_by_city, x='Discount', y=discount_sales_by_city['Sales'], color='City',
                 title='Discount and Sales per City')
fig.show()

# %%
plt.scatter(df["Discount"], df["Profit"])
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.show()

# %%
df.isnull().any()
# Out:
# Customer Name    False
# Category         False
# Sub_Category     False
# City             False
# Order_Date        True
# Region           False
# Sales            False
# Discount         False
# Profit           False
# Year              True
# dtype: bool

# %%
# remove rows with null values

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df_cleaned = df.dropna(subset=['Order_Date'])

print(df_cleaned)
# Out:
#      Customer Name          Category      Sub_Category         City  \
# 0           Harish      Oil & Masala           Masalas      Vellore
# 1            Sudha         Beverages     Health Drinks  Krishnagiri
# 2          Hussain       Food Grains      Atta & Flour   Perambalur
# 3          Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4          Ridhesh       Food Grains   Organic Staples         Ooty
# ...            ...               ...               ...          ...
# 9983          Peer       Food Grains              Rice    Nagercoil
# 9986          Peer            Bakery          Biscuits      Vellore
# 9988       Jackson            Snacks           Cookies      Vellore
# 9990          Alan            Bakery          Biscuits  Kanyakumari
# 9991          Ravi       Food Grains              Rice         Bodi
#
#      Order_Date Region  Sales  Discount  Profit    Year
# 0    2017-11-08  North   1254      0.12  401.28  2017.0
# 1    2017-11-08  South    749      0.18  149.80  2017.0
# 2    2017-06-12   West   2360      0.21  165.20  2017.0
# 3    2016-10-11  South    896      0.25   89.60  2016.0
# 4    2016-10-11  South   2355      0.26  918.45  2016.0
# ...         ...    ...    ...       ...     ...     ...
# 9983 2017-12-06   West   2335      0.17  607.10  2017.0
# 9986 2018-05-08   West   2199      0.34  153.93  2018.0
# 9988 2016-11-03   West   1460      0.15  452.60  2016.0
# 9990 2015-07-12   West   1195      0.26   71.70  2015.0
# 9991 2017-06-06   West   1567      0.16  501.44  2017.0
#
# [4042 rows x 10 columns]

# %%
df_cleaned.isnull().any()
# Out:
# Customer Name    False
# Category         False
# Sub_Category     False
# City             False
# Order_Date       False
# Region           False
# Sales            False
# Discount         False
# Profit           False
# Year             False
# dtype: bool

# %%
df_cleaned.head()
# Out:
#   Customer Name          Category      Sub_Category         City Order_Date  \
# 0        Harish      Oil & Masala           Masalas      Vellore 2017-11-08
# 1         Sudha         Beverages     Health Drinks  Krishnagiri 2017-11-08
# 2       Hussain       Food Grains      Atta & Flour   Perambalur 2017-06-12
# 3       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri 2016-10-11
# 4       Ridhesh       Food Grains   Organic Staples         Ooty 2016-10-11
#
#   Region  Sales  Discount  Profit    Year
# 0  North   1254      0.12  401.28  2017.0
# 1  South    749      0.18  149.80  2017.0
# 2   West   2360      0.21  165.20  2017.0
# 3  South    896      0.25   89.60  2016.0
# 4  South   2355      0.26  918.45  2016.0

# %%
df_cleaned.to_csv("cleaned_data.csv", index=False)
